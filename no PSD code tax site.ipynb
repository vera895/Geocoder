# %%
import pandas as pd
df = pd.read_excel('/Users/verafeng/Desktop/LCT_LancasterCountyTax/272601_psd_050420.xlsx')

# %%
df.shape
# Out:
# (272601, 27)

# %%
df.head(3)
# Out:
#    ACCOUNTXRE          ADDRESS1 ADDRESS2    CITY STATE COUNTRY  POSTALCODE  \
# 0      100000   124 PENNWICK DR      NaN  LITITZ    PA     NaN  17543-7623
# 1      100004  6 MEADOW VIEW DR      NaN   LEOLA    PA     NaN  17540-1650
# 2      100005  52 W LINCOLN AVE      NaN  LITITZ    PA     NaN  17543-1034
#
#   HOUSE_NUMB STREET_PRE          STREET  ...  DISTRICT ReportingYear  \
# 0        124        NaN     PENNWICK DR  ...       370        2020.0
# 1          6        NaN  MEADOW VIEW DR  ...       360        2020.0
# 2         52          W     LINCOLN AVE  ...       370        2020.0
#
#    Textbox137  MunicipalityID     Municipality_y SchoolDistrictID  \
# 0   LANCASTER        360933.0        LITITZ BORO         369003.0
# 1   LANCASTER        361625.0  UPPER LEACOCK TWP         361703.0
# 2   LANCASTER        360933.0        LITITZ BORO         369003.0
#
#      SchoolDistrictName  PSD_code      Municipality_clean  \
# ...

# %%
no_psd = df.loc[df['PSD_code'].isnull()]

# %%
no_psd.shape
# Out:
# (2406, 27)

# %%
# no_psd[['Municipality_clean','SchoolDistrictName_clean']].unqiue()
# pd.unique(no_psd['Municipality_clean','SchoolDistrictName_clean'])
no_psd.groupby(['Municipality_clean','SchoolDistrictName_clean']).size().reset_index()
# Out:
# Empty DataFrame
# Columns: [Municipality_clean, SchoolDistrictName_clean, 0]
# Index: []

# %%
no_psd.columns
# Out:
# Index(['ACCOUNTXRE', 'ADDRESS1', 'ADDRESS2', 'CITY', 'STATE', 'COUNTRY',
#        'POSTALCODE', 'HOUSE_NUMB', 'STREET_PRE', 'STREET', 'ZIPCODE',
#        'Owen_SCHOO', 'latitude', 'longitude', 'Parcel_ACCOUNT',
#        'SchoolDistrict_Name', 'Municipality_x', 'DISTRICT', 'ReportingYear',
#        'Textbox137', 'MunicipalityID', 'Municipality_y', 'SchoolDistrictID',
#        'SchoolDistrictName', 'PSD_code', 'Municipality_clean',
#        'SchoolDistrictName_clean'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', None)
no_psd.head(3)
# Out:
#      ACCOUNTXRE             ADDRESS1 ADDRESS2         CITY STATE COUNTRY  \
# 76       100197        142 LEPORE DR      NaN    LANCASTER    PA     NaN
# 221      100620        637 PETERS RD      NaN  NEW HOLLAND    PA     NaN
# 246      100704  1872 HARRISBURG AVE      NaN    MOUNT JOY    PA     NaN
#
#      POSTALCODE HOUSE_NUMB STREET_PRE          STREET  ZIPCODE  \
# 76   17602-2643        142        NaN       LEPORE DR    17602
# 221  17557-9508        637        NaN       PETERS RD    17557
# 246  17552-9573       1872        NaN  HARRISBURG AVE    17552
#
#              Owen_SCHOO   latitude  longitude Parcel_ACCOUNT  \
# 76     Conestoga Valley  40.042438 -76.263492  8100804000000
# 221   Eastern Lanc. Co.  40.063047 -76.082385  1902182200000
# 246  Elizabethtown Area  40.125265 -76.555724  1604323900000
#
#     SchoolDistrict_Name         Municipality_x  DISTRICT  ReportingYear  \
# 76     Conestoga Valley      CITY OF LANCASTER       330            NaN
# ...

# %%
no_psd.groupby(['SchoolDistrict_Name','Municipality_x']).size().reset_index().rename(columns={0:'count'}).sort_values(by='count', ascending= False)
# Out:
#         SchoolDistrict_Name           Municipality_x  count
# 5          Conestoga Valley        CITY OF LANCASTER    669
# 21       Lampeter Strasburg        CITY OF LANCASTER    330
# 26                Lancaster         MANHEIM TOWNSHIP    204
# 20                Hempfield           MANOR TOWNSHIP    138
# 11                  Donegal    WEST DONEGAL TOWNSHIP    106
# 3          Columbia Borough  WEST HEMPFIELD TOWNSHIP     76
# 28                Lancaster     MILLERSVILLE BOROUGH     64
# 56                  Warwick            PENN TOWNSHIP     59
# 55                  Warwick         MANHEIM TOWNSHIP     57
# 37            Octorara Area       SALISBURY TOWNSHIP     53
# 34         Manheim Township        CITY OF LANCASTER     50
# 40               Penn Manor   WEST LAMPETER TOWNSHIP     48
# 27                Lancaster           MANOR TOWNSHIP     43
# 14  Eastern Lancaster Count         EPHRATA TOWNSHIP     36
# 7          Conestoga Valley         EPHRATA TOWNSHIP     35
# ...
