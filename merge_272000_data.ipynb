# %%
import pandas as pd
import numpy as np

# %%
start = 0
gap = 10000

# %%
DFList = []
for x in range(27):
    start = x*10000
    data = pd.read_csv('/Users/verafeng/Desktop/LCT_LancasterCountyTax/TaxSite_coordinate_'+ str(start)+ '-' + str(start+gap) +'.csv')
    DFList.append(data)
#     print(DFList[x].head())
# data = pd.read_csv('/Users/verafeng/Desktop/LCT_LancasterCountyTax/TaxSite_coordinate_'+ str(start)+ '-' + str(start+gap) +'.csv')

# %%
DFList[0].head()
# Out:
#    Unnamed: 0  ACCOUNTXREFNUM              ADDRESS1 ADDRESS2       CITY STATE  \
# 0           0          100000       124 PENNWICK DR      NaN     LITITZ    PA
# 1           1          100004      6 MEADOW VIEW DR      NaN      LEOLA    PA
# 2           2          100005      52 W LINCOLN AVE      NaN     LITITZ    PA
# 3           3          100008  385 HOWARD AVE APT 8      NaN  LANCASTER    PA
# 4           4          100011   111 MILLER RD APT C      NaN      AKRON    PA
#
#    POSTALCODE  COUNTRY HOUSE_NUMBER STREET_PREFIX          STREET  ZIPCODE  \
# 0  17543-7623      NaN          124           NaN     PENNWICK DR    17543
# 1  17540-1650      NaN            6           NaN  MEADOW VIEW DR    17540
# 2  17543-1034      NaN           52             W     LINCOLN AVE    17543
# 3  17602-4237      NaN          385           NaN      HOWARD AVE    17602
# 4  17501-1178      NaN          111           NaN       MILLER RD    17501
#
# ...

# %%
#DFList[0], DFList[1]
output = DFList[0]
for x in range(26):
    x = x + 1
    frames = [output,DFList[x]]
    output = pd.concat(frames)

# %%
output
# Out:
#        Unnamed: 0  ACCOUNTXREFNUM              ADDRESS1 ADDRESS2       CITY  \
# 0               0          100000       124 PENNWICK DR      NaN     LITITZ
# 1               1          100004      6 MEADOW VIEW DR      NaN      LEOLA
# 2               2          100005      52 W LINCOLN AVE      NaN     LITITZ
# 3               3          100008  385 HOWARD AVE APT 8      NaN  LANCASTER
# 4               4          100011   111 MILLER RD APT C      NaN      AKRON
# ...           ...             ...                   ...      ...        ...
# 12595      272595          774933        1429 PICKET DR      NaN  LANCASTER
# 12596      272596          774934          230 BEECH ST      NaN     DENVER
# 12597      272597          774935        61 W CHURCH ST      NaN     DENVER
# 12598      272598          774936    840 COBBLESTONE LN      NaN  LANCASTER
# 12599      272599          774937      205 GREENLAND DR      NaN  LANCASTER
#
# ...

# %%
output.to_csv('/Users/verafeng/Desktop/LCT_LancasterCountyTax/Merged_with_none.csv')
