# %%
import pandas as pd
import geocoder

# %%
file = pd.read_excel("/Users/verafeng/Desktop/LCT_LancasterCountyTax/LancasterCountyTaxAccountList_coordinates.xlsx")

# %%
start = 150000
gap = 10000
file.shape
# Out:
# (272601, 13)

# %%
file.head()
# Out:
#    ACCOUNTXREFNUM              ADDRESS1 ADDRESS2       CITY STATE  POSTALCODE  \
# 0          100000       124 PENNWICK DR      NaN     LITITZ    PA  17543-7623
# 1          100004      6 MEADOW VIEW DR      NaN      LEOLA    PA  17540-1650
# 2          100005      52 W LINCOLN AVE      NaN     LITITZ    PA  17543-1034
# 3          100008  385 HOWARD AVE APT 8      NaN  LANCASTER    PA  17602-4237
# 4          100011   111 MILLER RD APT C      NaN      AKRON    PA  17501-1178
#
#   COUNTRY HOUSE_NUMBER STREET_PREFIX          STREET  ZIPCODE  \
# 0     NaN          124           NaN     PENNWICK DR    17543
# 1     NaN            6           NaN  MEADOW VIEW DR    17540
# 2     NaN           52             W     LINCOLN AVE    17543
# 3     NaN          385           NaN      HOWARD AVE    17602
# 4     NaN          111           NaN       MILLER RD    17501
#
#   Owen_SCHOOL_DISTRICT                                          address
# ...

# %%
file["address"]
# Out:
# 0                 124 PENNWICK DR, LITITZ ,PA ,17543-7623
# 1                 6 MEADOW VIEW DR, LEOLA ,PA ,17540-1650
# 2                52 W LINCOLN AVE, LITITZ ,PA ,17543-1034
# 3         385 HOWARD AVE APT 8, LANCASTER ,PA ,17602-4237
# 4              111 MILLER RD APT C, AKRON ,PA ,17501-1178
#                                ...
# 272596               230 BEECH ST, DENVER ,PA ,17517-8609
# 272597             61 W CHURCH ST, DENVER ,PA ,17517-9244
# 272598      840 COBBLESTONE LN, LANCASTER ,PA ,17601-3364
# 272599             205 GREENLAND DR, LANCASTER ,PA ,17602
# 272600       305 HARVESTVIEW N, MOUNT JOY ,PA ,17552-2020
# Name: address, Length: 272601, dtype: object

# %%
file["address"][start]
# Out:
# '785 PARK HILL DR, MANHEIM ,PA ,17545-2321'

# %%
address = []
print ('Start from ' + str(start+1) + ' to ' + str(start+gap))
for x in range(start, start+gap):
    address.append(file["address"][x])
address
len(address)
# Out:
# Start from 150001 to 160000
# 10000

# %%
cnt = start
coordinates = []
for i in address:
    g = geocoder.arcgis(i)
    cnt = cnt + 1
#     print (i + '\n')
    print(str(cnt)+ ':' + str(g.latlng) + '\n')
    coordinates.append(str(g.latlng))
# Out:
# 150001:[40.148019000000005, -76.38368849999999]
#
# 150002:[40.1433556788908, -76.58988671022574]
#
# 150003:[40.1433556788908, -76.58988671022574]
#
# 150004:[39.96043544575556, -76.15620792630851]
#
# 150005:[40.05948326423904, -76.54286653872119]
#
# 150006:[40.14408209077259, -76.5683578030758]
#
# 150007:[40.094912502654395, -76.66828364960466]
#
# 150008:[40.10422473881939, -76.64459007755796]
#
# 150009:[40.17026498724672, -76.59249807700971]
#
# 150010:[39.995590578134895, -76.24505163209086]
#
# 150011:[39.995590578134895, -76.24505163209086]
#
# 150012:[40.08727633553592, -76.66670810505508]
#
# 150013:[39.75653687085291, -76.21263541687345]
#
# 150014:[39.75653687085291, -76.21263541687345]
#
# 150015:[40.08855659755327, -76.39841230907707]
#
# 150016:[39.9946301132494, -76.24473702386177]
#
# 150017:[40.00251947711918, -76.33905818192055]
#
# 150018:[39.89220843028963, -76.34269355285852]
#
# 150019:[40.033866173754916, -76.32174130099833]
#
# ...

# %%
coordinates
# Out:
# ['[40.148019000000005, -76.38368849999999]',
#  '[40.1433556788908, -76.58988671022574]',
#  '[40.1433556788908, -76.58988671022574]',
#  '[39.96043544575556, -76.15620792630851]',
#  '[40.05948326423904, -76.54286653872119]',
#  '[40.14408209077259, -76.5683578030758]',
#  '[40.094912502654395, -76.66828364960466]',
#  '[40.10422473881939, -76.64459007755796]',
#  '[40.17026498724672, -76.59249807700971]',
#  '[39.995590578134895, -76.24505163209086]',
#  '[39.995590578134895, -76.24505163209086]',
#  '[40.08727633553592, -76.66670810505508]',
#  '[39.75653687085291, -76.21263541687345]',
#  '[39.75653687085291, -76.21263541687345]',
#  '[40.08855659755327, -76.39841230907707]',
#  '[39.9946301132494, -76.24473702386177]',
#  '[40.00251947711918, -76.33905818192055]',
#  '[39.89220843028963, -76.34269355285852]',
#  '[40.033866173754916, -76.32174130099833]',
#  '[40.086099588378, -76.30878898612153]',
#  '[40.05248291952786, -76.41069618457495]',
# ...

# %%
df = file.iloc[start:start+gap,:]

df['coordinates'] = coordinates
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.head(7)
# Out:
#         ACCOUNTXREFNUM            ADDRESS1         ADDRESS2           CITY  \
# 150000          512784    785 PARK HILL DR              NaN        MANHEIM
# 150001          512785  1129 S CHESTNUT ST              NaN  ELIZABETHTOWN
# 150002          512786  1129 S CHESTNUT ST              NaN  ELIZABETHTOWN
# 150003          512787          9 ROBBY LN              NaN      STRASBURG
# 150004          512793     546 E MARKET ST              NaN       MARIETTA
# 150005          512794    26 WATERFOWL WAY              NaN  ELIZABETHTOWN
# 150006          512796          PO BOX 504  240 CHESTNUT ST     BAINBRIDGE
#
#        STATE  POSTALCODE COUNTRY HOUSE_NUMBER STREET_PREFIX         STREET  \
# 150000    PA  17545-2321     NaN          785           NaN   PARK HILL DR
# 150001    PA  17022-2891     NaN         1129             S    CHESTNUT ST
# 150002    PA  17022-2891     NaN         1129             S    CHESTNUT ST
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.to_csv('/Users/verafeng/Desktop/LCT_LancasterCountyTax/TaxSite_coordinate_'+ str(start)+ '-' + str(start+gap) +'.csv')
