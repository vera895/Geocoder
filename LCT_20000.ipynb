# %%
import pandas as pd
import geocoder

# %%
file = pd.read_excel("/Users/verafeng/Desktop/LCT_LancasterCountyTax/LancasterCountyTaxAccountList_coordinates.xlsx")

# %%
file.shape
# Out:
# (272601, 13)

# %%
file.head()
# Out:
#    ACCOUNTXREFNUM              ADDRESS1 ADDRESS2       CITY STATE  POSTALCODE  \
# 0          100000       124 PENNWICK DR      NaN     LITITZ    PA  17543-7623
# 1          100004      6 MEADOW VIEW DR      NaN      LEOLA    PA  17540-1650
# 2          100005      52 W LINCOLN AVE      NaN     LITITZ    PA  17543-1034
# 3          100008  385 HOWARD AVE APT 8      NaN  LANCASTER    PA  17602-4237
# 4          100011   111 MILLER RD APT C      NaN      AKRON    PA  17501-1178
#
#   COUNTRY HOUSE_NUMBER STREET_PREFIX          STREET  ZIPCODE  \
# 0     NaN          124           NaN     PENNWICK DR    17543
# 1     NaN            6           NaN  MEADOW VIEW DR    17540
# 2     NaN           52             W     LINCOLN AVE    17543
# 3     NaN          385           NaN      HOWARD AVE    17602
# 4     NaN          111           NaN       MILLER RD    17501
#
#   Owen_SCHOOL_DISTRICT                                          address
# ...

# %%
file["address"]
# Out:
# 0                 124 PENNWICK DR, LITITZ ,PA ,17543-7623
# 1                 6 MEADOW VIEW DR, LEOLA ,PA ,17540-1650
# 2                52 W LINCOLN AVE, LITITZ ,PA ,17543-1034
# 3         385 HOWARD AVE APT 8, LANCASTER ,PA ,17602-4237
# 4              111 MILLER RD APT C, AKRON ,PA ,17501-1178
#                                ...
# 272596               230 BEECH ST, DENVER ,PA ,17517-8609
# 272597             61 W CHURCH ST, DENVER ,PA ,17517-9244
# 272598      840 COBBLESTONE LN, LANCASTER ,PA ,17601-3364
# 272599             205 GREENLAND DR, LANCASTER ,PA ,17602
# 272600       305 HARVESTVIEW N, MOUNT JOY ,PA ,17552-2020
# Name: address, Length: 272601, dtype: object

# %%
coordinates = []
address = []
for x in range(10000, 20000):
#for x in range(0, len(file)):
#     print(file["address"][x])
    address.append(file["address"][x])

# %%
address[0]
# Out:
# '148 SNAPDRAGON DR, LEOLA ,PA ,17540-1977'

# %%
cnt = 10000
for i in address:
    g = geocoder.arcgis(i)
    cnt = cnt + 1
    print(str(cnt)+ ':' + str(g.latlng))
    coordinates = str(g.latlng)
# Out:
# 10001:[40.09357234358602, -76.21447589174227]
# 10002:[40.123675163245224, -76.23159565667747]
# 10003:[40.14648448349582, -76.20114069995395]
# 10004:[40.14648448349582, -76.20114069995395]
# 10005:[40.154826279762275, -76.25916110286205]
# 10006:[40.17802829811281, -76.17640133469921]
# 10007:[40.091274, -76.18206548462099]
# 10008:[40.09027291589251, -76.1666391487966]
# 10009:[40.08997790700572, -76.21811536776491]
# 10010:[40.01649578711989, -76.24805564337225]
# 10011:[40.01649578711989, -76.24805564337225]
# 10012:[40.09107149486411, -76.1875770831552]
# 10013:[40.09107149486411, -76.1875770831552]
# 10014:[40.05558398277465, -76.35612509339832]
# 10015:[40.08858616567618, -76.20991450943505]
# 10016:[40.08858616567618, -76.20991450943505]
# 10017:[40.09022740051349, -76.1735234439379]
# 10018:[40.12937884817364, -76.22510728784103]
# 10019:[40.09726467805408, -76.1616569353109]
# 10020:[40.09726467805408, -76.1616569353109]
# 10021:[40.139378578711806, -76.1565519841883]
# ...

# %%
df = file.iloc[10000:20000,:]

df['coordinates'] = coordinates
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df.head(5)
# Out:
#        ACCOUNTXREFNUM                   ADDRESS1 ADDRESS2     CITY STATE  \
# 10000          125397          148 SNAPDRAGON DR      NaN    LEOLA    PA
# 10001          125400           130 ROSE HILL RD      NaN  EPHRATA    PA
# 10002          125402                312 POOL RD      NaN  EPHRATA    PA
# 10003          125403                312 POOL RD      NaN  EPHRATA    PA
# 10004          125404  112 ROTHSVILLE STATION RD      NaN   LITITZ    PA
#
#        POSTALCODE COUNTRY HOUSE_NUMBER STREET_PREFIX                 STREET  \
# 10000  17540-1977     NaN          148           NaN          SNAPDRAGON DR
# 10001  17522-9594     NaN          130           NaN           ROSE HILL RD
# 10002  17522-8719     NaN          312           NaN                POOL RD
# 10003  17522-8719     NaN          312           NaN                POOL RD
# 10004  17543-8541     NaN          112           NaN  ROTHSVILLE STATION RD
#
#        ZIPCODE Owen_SCHOOL_DISTRICT  \
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.to_csv('/Users/verafeng/Desktop/LCT_LancasterCountyTax/TaxSite_coordinate_20000.csv')
